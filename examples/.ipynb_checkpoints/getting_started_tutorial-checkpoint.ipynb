# %%
from sage.all import load, var, solve
import sys
import re
from collections import defaultdict
import pandas as pd
import numpy as np
import os
import pickle
import matplotlib.pyplot as plt
from scipy.stats import ranksums 
import time
from scipy.optimize import minimize
import math
from scipy.stats import poisson
import operator

# %%
sample = '0bfd1043-7346-fdd0-e050-11ac0c484cab'

# %%
sys.path.append('../package/')

# %%
import tau
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import tau
#
# File /n/data1/hms/dbmi/park/jbrew/Tau/Tau_github/python_workflow/examples/../package/tau/__init__.py:1
# ----> 1 from .trim import trim
#       2 from .revise import revise
#       3 from .categorize import categorize
#
# File /n/data1/hms/dbmi/park/jbrew/Tau/Tau_github/python_workflow/examples/../package/tau/trim.py:3
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 import pysam
#       4 import argparse
#       6 def trim(sample, snv_file, cnv_file, purity_file, output_file):
#
# ModuleNotFoundError: No module named 'pysam'
